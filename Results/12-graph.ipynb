# %%
import json
import matplotlib.pyplot as plt
import math

# %%
x = [i for i in range(1, 101)]

# %%
with open("bm25/bm25_1_0_modified.json", "r") as f:
    data_0 = json.load(f)
    counts_0 = [0 for i in range(101)]
    for element in data_0:
        counts_0[element["rank"]] += 1
    counts_0 = counts_0[1:]
    for i in range(len(counts_0)):
        counts_0[i] = math.log(counts_0[i] + 1, 2)
with open("BOW/BOW_1_0_modified.json", "r") as f:
    data_1 = json.load(f)
    counts_1= [0 for i in range(101)]
    for element in data_1:
        counts_1[element["rank"]] += 1
    counts_1 = counts_1[1:]
    for i in range(len(counts_1)):
        counts_1[i] = math.log(counts_1[i] + 1, 2)
with open("open_source/open_source_1_0_modified.json", "r") as f:
    data_2 = json.load(f)
    counts_2= [0 for i in range(101)]
    for element in data_2:
        counts_2[element["rank"]] += 1
    counts_2 = counts_2[1:]
    for i in range(len(counts_2)):
        counts_2[i] = math.log(counts_2[i] + 1, 2)
with open("RRF/rrf_1_0_modified.json", "r") as f:
    data_3 = json.load(f)
    counts_3= [0 for i in range(101)]
    for element in data_3:
        counts_3[element["rank"]] += 1
    counts_3 = counts_3[1:]
    for i in range(len(counts_3)):
        counts_3[i] = math.log(counts_3[i] + 1, 2)
with open("tf-idf/tf-idf_1_0_modified.json", "r") as f:
    data_4 = json.load(f)
    counts_4= [0 for i in range(101)]
    for element in data_4:
        counts_4[element["rank"]] += 1
    counts_4 = counts_4[1:]
    for i in range(len(counts_4)):
        counts_4[i] = math.log(counts_4[i] + 1, 2)
with open("vision/vision_1_0_modified.json", "r") as f:
    data_5 = json.load(f)
    counts_5= [0 for i in range(101)]
    for element in data_5:
        counts_5[element["rank"]] += 1
    counts_5 = counts_5[1:]
    for i in range(len(counts_5)):
        counts_5[i] = math.log(counts_5[i] + 1, 2)
plt.plot(x, counts_0, label='Line 1', color='blue')  # Line 1
plt.plot(x, counts_1, label='Line 2', color='red')  # Line 1
plt.plot(x, counts_2, label='Line 3', color='green')  # Line 1
plt.plot(x, counts_3, label='Line 4', color='yellow')  # Line 1
plt.plot(x, counts_4, label='Line 5', color='orange')  # Line 1
plt.plot(x, counts_5, label='Line 6', color='black')  # Line 1

# Add labels and title
plt.xlabel('Rank')
plt.ylabel('Retrieved')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
with open("bm25/bm25_1_0.json", "r") as f:
    data_0 = json.load(f)
    counts_0 = [0 for i in range(101)]
    for element in data_0:
        counts_0[element["rank"]] += 1
    counts_0 = counts_0[1:]
    for i in range(len(counts_0)):
        counts_0[i] = math.log(counts_0[i] + 1, 2)
with open("BOW/BOW_1_0.json", "r") as f:
    data_1 = json.load(f)
    counts_1= [0 for i in range(101)]
    for element in data_1:
        counts_1[element["rank"]] += 1
    counts_1 = counts_1[1:]
    for i in range(len(counts_1)):
        counts_1[i] = math.log(counts_1[i] + 1, 2)
with open("open_source/open_source_1_0.json", "r") as f:
    data_2 = json.load(f)
    counts_2= [0 for i in range(101)]
    for element in data_2:
        counts_2[element["rank"]] += 1
    counts_2 = counts_2[1:]
    for i in range(len(counts_2)):
        counts_2[i] = math.log(counts_2[i] + 1, 2)
with open("RRF/rrf_1_0_normal.json", "r") as f:
    data_3 = json.load(f)
    counts_3= [0 for i in range(101)]
    for element in data_3:
        counts_3[element["rank"]] += 1
    counts_3 = counts_3[1:]
    for i in range(len(counts_3)):
        counts_3[i] = math.log(counts_3[i] + 1, 2)
with open("tf-idf/tf-idf_1_0.json", "r") as f:
    data_4 = json.load(f)
    counts_4= [0 for i in range(101)]
    for element in data_4:
        counts_4[element["rank"]] += 1
    counts_4 = counts_4[1:]
    for i in range(len(counts_4)):
        counts_4[i] = math.log(counts_4[i] + 1, 2)
with open("vision/vision_1_0.json", "r") as f:
    data_5 = json.load(f)
    counts_5= [0 for i in range(101)]
    for element in data_5:
        counts_5[element["rank"]] += 1
    counts_5 = counts_5[1:]
    for i in range(len(counts_5)):
        counts_5[i] = math.log(counts_5[i] + 1, 2)
plt.plot(x, counts_0, label='Line 1', color='blue')  # Line 1
plt.plot(x, counts_1, label='Line 2', color='red')  # Line 1
plt.plot(x, counts_2, label='Line 3', color='green')  # Line 1
plt.plot(x, counts_3, label='Line 4', color='yellow')  # Line 1
plt.plot(x, counts_4, label='Line 5', color='orange')  # Line 1
plt.plot(x, counts_5, label='Line 6', color='black')  # Line 1

# Add labels and title
plt.xlabel('Rank')
plt.ylabel('Retrieved')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
with open("bm25/bm25_1_1_modified.json", "r") as f:
    data_0 = json.load(f)
    counts_0 = [0 for i in range(101)]
    for element in data_0:
        counts_0[element["rank"]] += 1
    counts_0 = counts_0[1:]
    for i in range(len(counts_0)):
        counts_0[i] = math.log(counts_0[i] + 1, 2)
with open("BOW/BOW_1_1_modified.json", "r") as f:
    data_1 = json.load(f)
    counts_1= [0 for i in range(101)]
    for element in data_1:
        counts_1[element["rank"]] += 1
    counts_1 = counts_1[1:]
    for i in range(len(counts_1)):
        counts_1[i] = math.log(counts_1[i] + 1, 2)
with open("open_source/open_source_1_1_modified.json", "r") as f:
    data_2 = json.load(f)
    counts_2= [0 for i in range(101)]
    for element in data_2:
        counts_2[element["rank"]] += 1
    counts_2 = counts_2[1:]
    for i in range(len(counts_2)):
        counts_2[i] = math.log(counts_2[i] + 1, 2)
with open("RRF/rrf_1_1_modified.json", "r") as f:
    data_3 = json.load(f)
    counts_3= [0 for i in range(101)]
    for element in data_3:
        counts_3[element["rank"]] += 1
    counts_3 = counts_3[1:]
    for i in range(len(counts_3)):
        counts_3[i] = math.log(counts_3[i] + 1, 2)
with open("tf-idf/tf-idf_1_1_modified.json", "r") as f:
    data_4 = json.load(f)
    counts_4= [0 for i in range(101)]
    for element in data_4:
        counts_4[element["rank"]] += 1
    counts_4 = counts_4[1:]
    for i in range(len(counts_4)):
        counts_4[i] = math.log(counts_4[i] + 1, 2)
with open("vision/vision_1_1_modified.json", "r") as f:
    data_5 = json.load(f)
    counts_5= [0 for i in range(101)]
    for element in data_5:
        counts_5[element["rank"]] += 1
    counts_5 = counts_5[1:]
    for i in range(len(counts_5)):
        counts_5[i] = math.log(counts_5[i] + 1, 2)
plt.plot(x, counts_0, label='Line 1', color='blue')  # Line 1
plt.plot(x, counts_1, label='Line 2', color='red')  # Line 1
plt.plot(x, counts_2, label='Line 3', color='green')  # Line 1
plt.plot(x, counts_3, label='Line 4', color='yellow')  # Line 1
plt.plot(x, counts_4, label='Line 5', color='orange')  # Line 1
plt.plot(x, counts_5, label='Line 6', color='black')  # Line 1

# Add labels and title
plt.xlabel('Rank')
plt.ylabel('Retrieved')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
with open("bm25/bm25_1_1.json", "r") as f:
    data_0 = json.load(f)
    counts_0 = [0 for i in range(101)]
    for element in data_0:
        counts_0[element["rank"]] += 1
    counts_0 = counts_0[1:]
    for i in range(len(counts_0)):
        counts_0[i] = math.log(counts_0[i] + 1, 2)
with open("BOW/BOW_1_1.json", "r") as f:
    data_1 = json.load(f)
    counts_1= [0 for i in range(101)]
    for element in data_1:
        counts_1[element["rank"]] += 1
    counts_1 = counts_1[1:]
    for i in range(len(counts_1)):
        counts_1[i] = math.log(counts_1[i] + 1, 2)
with open("open_source/open_source_1_1.json", "r") as f:
    data_2 = json.load(f)
    counts_2= [0 for i in range(101)]
    for element in data_2:
        counts_2[element["rank"]] += 1
    counts_2 = counts_2[1:]
    for i in range(len(counts_2)):
        counts_2[i] = math.log(counts_2[i] + 1, 2)
with open("RRF/rrf_1_1_normal.json", "r") as f:
    data_3 = json.load(f)
    counts_3= [0 for i in range(101)]
    for element in data_3:
        counts_3[element["rank"]] += 1
    counts_3 = counts_3[1:]
    for i in range(len(counts_3)):
        counts_3[i] = math.log(counts_3[i] + 1, 2)
with open("tf-idf/tf-idf_1_1.json", "r") as f:
    data_4 = json.load(f)
    counts_4= [0 for i in range(101)]
    for element in data_4:
        counts_4[element["rank"]] += 1
    counts_4 = counts_4[1:]
    for i in range(len(counts_4)):
        counts_4[i] = math.log(counts_4[i] + 1, 2)
with open("vision/vision_1_1.json", "r") as f:
    data_5 = json.load(f)
    counts_5= [0 for i in range(101)]
    for element in data_5:
        counts_5[element["rank"]] += 1
    counts_5 = counts_5[1:]
    for i in range(len(counts_5)):
        counts_5[i] = math.log(counts_5[i] + 1, 2)
plt.plot(x, counts_0, label='Line 1', color='blue')  # Line 1
plt.plot(x, counts_1, label='Line 2', color='red')  # Line 1
plt.plot(x, counts_2, label='Line 3', color='green')  # Line 1
plt.plot(x, counts_3, label='Line 4', color='yellow')  # Line 1
plt.plot(x, counts_4, label='Line 5', color='orange')  # Line 1
plt.plot(x, counts_5, label='Line 6', color='black')  # Line 1

# Add labels and title
plt.xlabel('Rank')
plt.ylabel('Retrieved')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
with open("bm25/bm25_1_2_modified.json", "r") as f:
    data_0 = json.load(f)
    counts_0 = [0 for i in range(101)]
    for element in data_0:
        counts_0[element["rank"]] += 1
    counts_0 = counts_0[1:]
    for i in range(len(counts_0)):
        counts_0[i] = math.log(counts_0[i] + 1, 2)
with open("BOW/BOW_1_2_modified.json", "r") as f:
    data_1 = json.load(f)
    counts_1= [0 for i in range(101)]
    for element in data_1:
        counts_1[element["rank"]] += 1
    counts_1 = counts_1[1:]
    for i in range(len(counts_1)):
        counts_1[i] = math.log(counts_1[i] + 1, 2)
with open("open_source/open_source_1_2_modified.json", "r") as f:
    data_2 = json.load(f)
    counts_2= [0 for i in range(101)]
    for element in data_2:
        counts_2[element["rank"]] += 1
    counts_2 = counts_2[1:]
    for i in range(len(counts_2)):
        counts_2[i] = math.log(counts_2[i] + 1, 2)
with open("RRF/rrf_1_2_modified.json", "r") as f:
    data_3 = json.load(f)
    counts_3= [0 for i in range(101)]
    for element in data_3:
        counts_3[element["rank"]] += 1
    counts_3 = counts_3[1:]
    for i in range(len(counts_3)):
        counts_3[i] = math.log(counts_3[i] + 1, 2)
with open("tf-idf/tf-idf_1_2_modified.json", "r") as f:
    data_4 = json.load(f)
    counts_4= [0 for i in range(101)]
    for element in data_4:
        counts_4[element["rank"]] += 1
    counts_4 = counts_4[1:]
    for i in range(len(counts_4)):
        counts_4[i] = math.log(counts_4[i] + 1, 2)
with open("vision/vision_1_2_modified.json", "r") as f:
    data_5 = json.load(f)
    counts_5= [0 for i in range(101)]
    for element in data_5:
        counts_5[element["rank"]] += 1
    counts_5 = counts_5[1:]
    for i in range(len(counts_5)):
        counts_5[i] = math.log(counts_5[i] + 1, 2)
plt.plot(x, counts_0, label='Line 1', color='blue')  # Line 1
plt.plot(x, counts_1, label='Line 2', color='red')  # Line 1
plt.plot(x, counts_2, label='Line 3', color='green')  # Line 1
plt.plot(x, counts_3, label='Line 4', color='yellow')  # Line 1
plt.plot(x, counts_4, label='Line 5', color='orange')  # Line 1
plt.plot(x, counts_5, label='Line 6', color='black')  # Line 1

# Add labels and title
plt.xlabel('Rank')
plt.ylabel('Retrieved')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
with open("bm25/bm25_1_2.json", "r") as f:
    data_0 = json.load(f)
    counts_0 = [0 for i in range(101)]
    for element in data_0:
        counts_0[element["rank"]] += 1
    counts_0 = counts_0[1:]
    for i in range(len(counts_0)):
        counts_0[i] = math.log(counts_0[i] + 1, 2)
with open("BOW/BOW_1_2.json", "r") as f:
    data_1 = json.load(f)
    counts_1= [0 for i in range(101)]
    for element in data_1:
        counts_1[element["rank"]] += 1
    counts_1 = counts_1[1:]
    for i in range(len(counts_1)):
        counts_1[i] = math.log(counts_1[i] + 1, 2)
with open("open_source/open_source_1_2.json", "r") as f:
    data_2 = json.load(f)
    counts_2= [0 for i in range(101)]
    for element in data_2:
        counts_2[element["rank"]] += 1
    counts_2 = counts_2[1:]
    for i in range(len(counts_2)):
        counts_2[i] = math.log(counts_2[i] + 1, 2)
with open("RRF/rrf_1_2_normal.json", "r") as f:
    data_3 = json.load(f)
    counts_3= [0 for i in range(101)]
    for element in data_3:
        counts_3[element["rank"]] += 1
    counts_3 = counts_3[1:]
    for i in range(len(counts_3)):
        counts_3[i] = math.log(counts_3[i] + 1, 2)
with open("tf-idf/tf-idf_1_2.json", "r") as f:
    data_4 = json.load(f)
    counts_4= [0 for i in range(101)]
    for element in data_4:
        counts_4[element["rank"]] += 1
    counts_4 = counts_4[1:]
    for i in range(len(counts_4)):
        counts_4[i] = math.log(counts_4[i] + 1, 2)
with open("vision/vision_1_2.json", "r") as f:
    data_5 = json.load(f)
    counts_5= [0 for i in range(101)]
    for element in data_5:
        counts_5[element["rank"]] += 1
    counts_5 = counts_5[1:]
    for i in range(len(counts_5)):
        counts_5[i] = math.log(counts_5[i] + 1, 2)
plt.plot(x, counts_0, label='Line 1', color='blue')  # Line 1
plt.plot(x, counts_1, label='Line 2', color='red')  # Line 1
plt.plot(x, counts_2, label='Line 3', color='green')  # Line 1
plt.plot(x, counts_3, label='Line 4', color='yellow')  # Line 1
plt.plot(x, counts_4, label='Line 5', color='orange')  # Line 1
plt.plot(x, counts_5, label='Line 6', color='black')  # Line 1

# Add labels and title
plt.xlabel('Rank')
plt.ylabel('Retrieved')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
with open("bm25/bm25_1_0_modified.json", "r") as f:
    data_0 = json.load(f)
    counts_0 = [0 for i in range(101)]
    for element in data_0:
        counts_0[element["rank"]] += 1
    counts_0 = counts_0[1:]
    for i in range(len(counts_0)):
        if(i - 1 > -1):
            counts_0[i] += counts_0[i - 1]
    for i in range(len(counts_0)):
        counts_0[i] = math.log(counts_0[i] + 1, 2)
with open("BOW/BOW_1_0_modified.json", "r") as f:
    data_1 = json.load(f)
    counts_1= [0 for i in range(101)]
    for element in data_1:
        counts_1[element["rank"]] += 1
    counts_1 = counts_1[1:]
    for i in range(len(counts_1)):
        if(i - 1 > -1):
            counts_1[i] += counts_1[i - 1]
    for i in range(len(counts_1)):
        counts_1[i] = math.log(counts_1[i] + 1, 2)
with open("open_source/open_source_1_0_modified.json", "r") as f:
    data_2 = json.load(f)
    counts_2= [0 for i in range(101)]
    for element in data_2:
        counts_2[element["rank"]] += 1
    counts_2 = counts_2[1:]
    for i in range(len(counts_2)):
        if(i - 1 > -1):
            counts_2[i] += counts_2[i - 1]
    for i in range(len(counts_2)):
        counts_2[i] = math.log(counts_2[i] + 1, 2)
with open("RRF/rrf_1_0_modified.json", "r") as f:
    data_3 = json.load(f)
    counts_3= [0 for i in range(101)]
    for element in data_3:
        counts_3[element["rank"]] += 1
    counts_3 = counts_3[1:]
    for i in range(len(counts_3)):
        if(i - 1 > -1):
            counts_3[i] += counts_3[i - 1]
    for i in range(len(counts_3)):
        counts_3[i] = math.log(counts_3[i] + 1, 2)
with open("tf-idf/tf-idf_1_0_modified.json", "r") as f:
    data_4 = json.load(f)
    counts_4= [0 for i in range(101)]
    for element in data_4:
        counts_4[element["rank"]] += 1
    counts_4 = counts_4[1:]
    for i in range(len(counts_4)):
        if(i - 1 > -1):
            counts_4[i] += counts_4[i - 1]
    for i in range(len(counts_4)):
        counts_4[i] = math.log(counts_4[i] + 1, 2)
with open("vision/vision_1_0_modified.json", "r") as f:
    data_5 = json.load(f)
    counts_5= [0 for i in range(101)]
    for element in data_5:
        counts_5[element["rank"]] += 1
    counts_5 = counts_5[1:]
    for i in range(len(counts_5)):
        if(i - 1 > -1):
            counts_5[i] += counts_5[i - 1]
    for i in range(len(counts_5)):
        counts_5[i] = math.log(counts_5[i] + 1, 2)
plt.plot(x, counts_0, label='Line 1', color='blue')  # Line 1
plt.plot(x, counts_1, label='Line 2', color='red')  # Line 1
plt.plot(x, counts_2, label='Line 3', color='green')  # Line 1
plt.plot(x, counts_3, label='Line 4', color='yellow')  # Line 1
plt.plot(x, counts_4, label='Line 5', color='orange')  # Line 1
plt.plot(x, counts_5, label='Line 6', color='black')  # Line 1

# Add labels and title
plt.xlabel('Rank')
plt.ylabel('Retrieved')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
with open("bm25/bm25_1_0.json", "r") as f:
    data_0 = json.load(f)
    counts_0 = [0 for i in range(101)]
    for element in data_0:
        counts_0[element["rank"]] += 1
    counts_0 = counts_0[1:]
    for i in range(len(counts_0)):
        if(i - 1 > -1):
            counts_0[i] += counts_0[i - 1]
    for i in range(len(counts_0)):
        counts_0[i] = math.log(counts_0[i] + 1, 2)
with open("BOW/BOW_1_0.json", "r") as f:
    data_1 = json.load(f)
    counts_1= [0 for i in range(101)]
    for element in data_1:
        counts_1[element["rank"]] += 1
    counts_1 = counts_1[1:]
    for i in range(len(counts_1)):
        if(i - 1 > -1):
            counts_1[i] += counts_1[i - 1]
    for i in range(len(counts_1)):
        counts_1[i] = math.log(counts_1[i] + 1, 2)
with open("open_source/open_source_1_0.json", "r") as f:
    data_2 = json.load(f)
    counts_2= [0 for i in range(101)]
    for element in data_2:
        counts_2[element["rank"]] += 1
    counts_2 = counts_2[1:]
    for i in range(len(counts_2)):
        if(i - 1 > -1):
            counts_2[i] += counts_2[i - 1]
    for i in range(len(counts_2)):
        counts_2[i] = math.log(counts_2[i] + 1, 2)
with open("RRF/rrf_1_0_normal.json", "r") as f:
    data_3 = json.load(f)
    counts_3= [0 for i in range(101)]
    for element in data_3:
        counts_3[element["rank"]] += 1
    counts_3 = counts_3[1:]
    for i in range(len(counts_3)):
        if(i - 1 > -1):
            counts_3[i] += counts_3[i - 1]
    for i in range(len(counts_3)):
        counts_3[i] = math.log(counts_3[i] + 1, 2)
with open("tf-idf/tf-idf_1_0.json", "r") as f:
    data_4 = json.load(f)
    counts_4= [0 for i in range(101)]
    for element in data_4:
        counts_4[element["rank"]] += 1
    counts_4 = counts_4[1:]
    for i in range(len(counts_4)):
        if(i - 1 > -1):
            counts_4[i] += counts_4[i - 1]
    for i in range(len(counts_4)):
        counts_4[i] = math.log(counts_4[i] + 1, 2)
with open("vision/vision_1_0.json", "r") as f:
    data_5 = json.load(f)
    counts_5= [0 for i in range(101)]
    for element in data_5:
        counts_5[element["rank"]] += 1
    counts_5 = counts_5[1:]
    for i in range(len(counts_5)):
        if(i - 1 > -1):
            counts_5[i] += counts_5[i - 1]
    for i in range(len(counts_5)):
        counts_5[i] = math.log(counts_5[i] + 1, 2)
plt.plot(x, counts_0, label='Line 1', color='blue')  # Line 1
plt.plot(x, counts_1, label='Line 2', color='red')  # Line 1
plt.plot(x, counts_2, label='Line 3', color='green')  # Line 1
plt.plot(x, counts_3, label='Line 4', color='yellow')  # Line 1
plt.plot(x, counts_4, label='Line 5', color='orange')  # Line 1
plt.plot(x, counts_5, label='Line 6', color='black')  # Line 1

# Add labels and title
plt.xlabel('Rank')
plt.ylabel('Retrieved')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
with open("bm25/bm25_1_1_modified.json", "r") as f:
    data_0 = json.load(f)
    counts_0 = [0 for i in range(101)]
    for element in data_0:
        counts_0[element["rank"]] += 1
    counts_0 = counts_0[1:]
    for i in range(len(counts_0)):
        if(i - 1 > -1):
            counts_0[i] += counts_0[i - 1]
    for i in range(len(counts_0)):
        counts_0[i] = math.log(counts_0[i] + 1, 2)
with open("BOW/BOW_1_1_modified.json", "r") as f:
    data_1 = json.load(f)
    counts_1= [0 for i in range(101)]
    for element in data_1:
        counts_1[element["rank"]] += 1
    counts_1 = counts_1[1:]
    for i in range(len(counts_1)):
        if(i - 1 > -1):
            counts_1[i] += counts_1[i - 1]
    for i in range(len(counts_1)):
        counts_1[i] = math.log(counts_1[i] + 1, 2)
with open("open_source/open_source_1_1_modified.json", "r") as f:
    data_2 = json.load(f)
    counts_2= [0 for i in range(101)]
    for element in data_2:
        counts_2[element["rank"]] += 1
    counts_2 = counts_2[1:]
    for i in range(len(counts_2)):
        if(i - 1 > -1):
            counts_2[i] += counts_2[i - 1]
    for i in range(len(counts_2)):
        counts_2[i] = math.log(counts_2[i] + 1, 2)
with open("RRF/rrf_1_1_modified.json", "r") as f:
    data_3 = json.load(f)
    counts_3= [0 for i in range(101)]
    for element in data_3:
        counts_3[element["rank"]] += 1
    counts_3 = counts_3[1:]
    for i in range(len(counts_3)):
        if(i - 1 > -1):
            counts_3[i] += counts_3[i - 1]
    for i in range(len(counts_3)):
        counts_3[i] = math.log(counts_3[i] + 1, 2)
with open("tf-idf/tf-idf_1_1_modified.json", "r") as f:
    data_4 = json.load(f)
    counts_4= [0 for i in range(101)]
    for element in data_4:
        counts_4[element["rank"]] += 1
    counts_4 = counts_4[1:]
    for i in range(len(counts_4)):
        if(i - 1 > -1):
            counts_4[i] += counts_4[i - 1]
    for i in range(len(counts_4)):
        counts_4[i] = math.log(counts_4[i] + 1, 2)
with open("vision/vision_1_1_modified.json", "r") as f:
    data_5 = json.load(f)
    counts_5= [0 for i in range(101)]
    for element in data_5:
        counts_5[element["rank"]] += 1
    counts_5 = counts_5[1:]
    for i in range(len(counts_5)):
        if(i - 1 > -1):
            counts_5[i] += counts_5[i - 1]
    for i in range(len(counts_5)):
        counts_5[i] = math.log(counts_5[i] + 1, 2)
plt.plot(x, counts_0, label='Line 1', color='blue')  # Line 1
plt.plot(x, counts_1, label='Line 2', color='red')  # Line 1
plt.plot(x, counts_2, label='Line 3', color='green')  # Line 1
plt.plot(x, counts_3, label='Line 4', color='yellow')  # Line 1
plt.plot(x, counts_4, label='Line 5', color='orange')  # Line 1
plt.plot(x, counts_5, label='Line 6', color='black')  # Line 1

# Add labels and title
plt.xlabel('Rank')
plt.ylabel('Retrieved')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
with open("bm25/bm25_1_1.json", "r") as f:
    data_0 = json.load(f)
    counts_0 = [0 for i in range(101)]
    for element in data_0:
        counts_0[element["rank"]] += 1
    counts_0 = counts_0[1:]
    for i in range(len(counts_0)):
        if(i - 1 > -1):
            counts_0[i] += counts_0[i - 1]
    for i in range(len(counts_0)):
        counts_0[i] = math.log(counts_0[i] + 1, 2)
with open("BOW/BOW_1_1.json", "r") as f:
    data_1 = json.load(f)
    counts_1= [0 for i in range(101)]
    for element in data_1:
        counts_1[element["rank"]] += 1
    counts_1 = counts_1[1:]
    for i in range(len(counts_1)):
        if(i - 1 > -1):
            counts_1[i] += counts_1[i - 1]
    for i in range(len(counts_1)):
        counts_1[i] = math.log(counts_1[i] + 1, 2)
with open("open_source/open_source_1_1.json", "r") as f:
    data_2 = json.load(f)
    counts_2= [0 for i in range(101)]
    for element in data_2:
        counts_2[element["rank"]] += 1
    counts_2 = counts_2[1:]
    for i in range(len(counts_2)):
        if(i - 1 > -1):
            counts_2[i] += counts_2[i - 1]
    for i in range(len(counts_2)):
        counts_2[i] = math.log(counts_2[i] + 1, 2)
with open("RRF/rrf_1_1_normal.json", "r") as f:
    data_3 = json.load(f)
    counts_3= [0 for i in range(101)]
    for element in data_3:
        counts_3[element["rank"]] += 1
    counts_3 = counts_3[1:]
    for i in range(len(counts_3)):
        if(i - 1 > -1):
            counts_3[i] += counts_3[i - 1]
    for i in range(len(counts_3)):
        counts_3[i] = math.log(counts_3[i] + 1, 2)
with open("tf-idf/tf-idf_1_1.json", "r") as f:
    data_4 = json.load(f)
    counts_4= [0 for i in range(101)]
    for element in data_4:
        counts_4[element["rank"]] += 1
    counts_4 = counts_4[1:]
    for i in range(len(counts_4)):
        if(i - 1 > -1):
            counts_4[i] += counts_4[i - 1]
    for i in range(len(counts_4)):
        counts_4[i] = math.log(counts_4[i] + 1, 2)
with open("vision/vision_1_1.json", "r") as f:
    data_5 = json.load(f)
    counts_5= [0 for i in range(101)]
    for element in data_5:
        counts_5[element["rank"]] += 1
    counts_5 = counts_5[1:]
    for i in range(len(counts_5)):
        if(i - 1 > -1):
            counts_5[i] += counts_5[i - 1]
    for i in range(len(counts_5)):
        counts_5[i] = math.log(counts_5[i] + 1, 2)
plt.plot(x, counts_0, label='Line 1', color='blue')  # Line 1
plt.plot(x, counts_1, label='Line 2', color='red')  # Line 1
plt.plot(x, counts_2, label='Line 3', color='green')  # Line 1
plt.plot(x, counts_3, label='Line 4', color='yellow')  # Line 1
plt.plot(x, counts_4, label='Line 5', color='orange')  # Line 1
plt.plot(x, counts_5, label='Line 6', color='black')  # Line 1

# Add labels and title
plt.xlabel('Rank')
plt.ylabel('Retrieved')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
with open("bm25/bm25_1_2_modified.json", "r") as f:
    data_0 = json.load(f)
    counts_0 = [0 for i in range(101)]
    for element in data_0:
        counts_0[element["rank"]] += 1
    counts_0 = counts_0[1:]
    for i in range(len(counts_0)):
        if(i - 1 > -1):
            counts_0[i] += counts_0[i - 1]
    for i in range(len(counts_0)):
        counts_0[i] = math.log(counts_0[i] + 1, 2)
with open("BOW/BOW_1_2_modified.json", "r") as f:
    data_1 = json.load(f)
    counts_1= [0 for i in range(101)]
    for element in data_1:
        counts_1[element["rank"]] += 1
    counts_1 = counts_1[1:]
    for i in range(len(counts_1)):
        if(i - 1 > -1):
            counts_1[i] += counts_1[i - 1]
    for i in range(len(counts_1)):
        counts_1[i] = math.log(counts_1[i] + 1, 2)
with open("open_source/open_source_1_2_modified.json", "r") as f:
    data_2 = json.load(f)
    counts_2= [0 for i in range(101)]
    for element in data_2:
        counts_2[element["rank"]] += 1
    counts_2 = counts_2[1:]
    for i in range(len(counts_2)):
        if(i - 1 > -1):
            counts_2[i] += counts_2[i - 1]
    for i in range(len(counts_2)):
        counts_2[i] = math.log(counts_2[i] + 1, 2)
with open("RRF/rrf_1_2_modified.json", "r") as f:
    data_3 = json.load(f)
    counts_3= [0 for i in range(101)]
    for element in data_3:
        counts_3[element["rank"]] += 1
    counts_3 = counts_3[1:]
    for i in range(len(counts_3)):
        if(i - 1 > -1):
            counts_3[i] += counts_3[i - 1]
    for i in range(len(counts_3)):
        counts_3[i] = math.log(counts_3[i] + 1, 2)
with open("tf-idf/tf-idf_1_2_modified.json", "r") as f:
    data_4 = json.load(f)
    counts_4= [0 for i in range(101)]
    for element in data_4:
        counts_4[element["rank"]] += 1
    counts_4 = counts_4[1:]
    for i in range(len(counts_4)):
        if(i - 1 > -1):
            counts_4[i] += counts_4[i - 1]
    for i in range(len(counts_4)):
        counts_4[i] = math.log(counts_4[i] + 1, 2)
with open("vision/vision_1_2_modified.json", "r") as f:
    data_5 = json.load(f)
    counts_5= [0 for i in range(101)]
    for element in data_5:
        counts_5[element["rank"]] += 1
    counts_5 = counts_5[1:]
    for i in range(len(counts_5)):
        if(i - 1 > -1):
            counts_5[i] += counts_5[i - 1]
    for i in range(len(counts_5)):
        counts_5[i] = math.log(counts_5[i] + 1, 2)
plt.plot(x, counts_0, label='Line 1', color='blue')  # Line 1
plt.plot(x, counts_1, label='Line 2', color='red')  # Line 1
plt.plot(x, counts_2, label='Line 3', color='green')  # Line 1
plt.plot(x, counts_3, label='Line 4', color='yellow')  # Line 1
plt.plot(x, counts_4, label='Line 5', color='orange')  # Line 1
plt.plot(x, counts_5, label='Line 6', color='black')  # Line 1

# Add labels and title
plt.xlabel('Rank')
plt.ylabel('Retrieved')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
with open("bm25/bm25_1_2.json", "r") as f:
    data_0 = json.load(f)
    counts_0 = [0 for i in range(101)]
    for element in data_0:
        counts_0[element["rank"]] += 1
    counts_0 = counts_0[1:]
    for i in range(len(counts_0)):
        if(i - 1 > -1):
            counts_0[i] += counts_0[i - 1]
    for i in range(len(counts_0)):
        counts_0[i] = math.log(counts_0[i] + 1, 2)
with open("BOW/BOW_1_2.json", "r") as f:
    data_1 = json.load(f)
    counts_1= [0 for i in range(101)]
    for element in data_1:
        counts_1[element["rank"]] += 1
    counts_1 = counts_1[1:]
    for i in range(len(counts_1)):
        if(i - 1 > -1):
            counts_1[i] += counts_1[i - 1]
    for i in range(len(counts_1)):
        counts_1[i] = math.log(counts_1[i] + 1, 2)
with open("open_source/open_source_1_2.json", "r") as f:
    data_2 = json.load(f)
    counts_2= [0 for i in range(101)]
    for element in data_2:
        counts_2[element["rank"]] += 1
    counts_2 = counts_2[1:]
    for i in range(len(counts_2)):
        if(i - 1 > -1):
            counts_2[i] += counts_2[i - 1]
    for i in range(len(counts_2)):
        counts_2[i] = math.log(counts_2[i] + 1, 2)
with open("RRF/rrf_1_2_normal.json", "r") as f:
    data_3 = json.load(f)
    counts_3= [0 for i in range(101)]
    for element in data_3:
        counts_3[element["rank"]] += 1
    counts_3 = counts_3[1:]
    for i in range(len(counts_3)):
        if(i - 1 > -1):
            counts_3[i] += counts_3[i - 1]
    for i in range(len(counts_3)):
        counts_3[i] = math.log(counts_3[i] + 1, 2)
with open("tf-idf/tf-idf_1_2.json", "r") as f:
    data_4 = json.load(f)
    counts_4= [0 for i in range(101)]
    for element in data_4:
        counts_4[element["rank"]] += 1
    counts_4 = counts_4[1:]
    for i in range(len(counts_4)):
        if(i - 1 > -1):
            counts_4[i] += counts_4[i - 1]
    for i in range(len(counts_4)):
        counts_4[i] = math.log(counts_4[i] + 1, 2)
with open("vision/vision_1_2.json", "r") as f:
    data_5 = json.load(f)
    counts_5= [0 for i in range(101)]
    for element in data_5:
        counts_5[element["rank"]] += 1
    counts_5 = counts_5[1:]
    for i in range(len(counts_5)):
        if(i - 1 > -1):
            counts_5[i] += counts_5[i - 1]
    for i in range(len(counts_5)):
        counts_5[i] = math.log(counts_5[i] + 1, 2)
plt.plot(x, counts_0, label='Line 1', color='blue')  # Line 1
plt.plot(x, counts_1, label='Line 2', color='red')  # Line 1
plt.plot(x, counts_2, label='Line 3', color='green')  # Line 1
plt.plot(x, counts_3, label='Line 4', color='yellow')  # Line 1
plt.plot(x, counts_4, label='Line 5', color='orange')  # Line 1
plt.plot(x, counts_5, label='Line 6', color='black')  # Line 1

# Add labels and title
plt.xlabel('Rank')
plt.ylabel('Retrieved')

# Add legend
plt.legend()

# Show plot
plt.show()
